# %%
#Import libraries
import os
import pandas as pd
import numpy as np

#import libraries for plots
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline
# Out:
# UsageError: Line magic function `%` not found.

# %%
#Read the csv file
day = pd.read_csv("day.csv", sep=",")

# %%
#Get the number of rows and columns
day.shape
# Out:
# (731, 16)

# %%
day.head()
# Out:
#    instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0        1  2011-01-01       1   0     1        0        6           0
# 1        2  2011-01-02       1   0     1        0        0           0
# 2        3  2011-01-03       1   0     1        0        1           1
# 3        4  2011-01-04       1   0     1        0        2           1
# 4        5  2011-01-05       1   0     1        0        3           1
#
#    weathersit      temp     atemp       hum  windspeed  casual  registered  \
# 0           2  0.344167  0.363625  0.805833   0.160446     331         654
# 1           2  0.363478  0.353739  0.696087   0.248539     131         670
# 2           1  0.196364  0.189405  0.437273   0.248309     120        1229
# 3           1  0.200000  0.212122  0.590435   0.160296     108        1454
# 4           1  0.226957  0.229270  0.436957   0.186900      82        1518
#
#     cnt
# 0   985
# 1   801
# 2  1349
# 3  1562
# 4  1600

# %%
#Get the data types of variables
print(day.dtypes)
# Out:
# instant         int64
# dteday         object
# season          int64
# yr              int64
# mnth            int64
# holiday         int64
# weekday         int64
# workingday      int64
# weathersit      int64
# temp          float64
# atemp         float64
# hum           float64
# windspeed     float64
# casual          int64
# registered      int64
# cnt             int64
# dtype: object

# %%
#Create a new dataframe containing required columns and creating new columns
df = day.copy()

#Create new columns
df['actual_temp'] = day['temp'] * 39
df['actual_feel_temp'] = day['atemp'] * 50
df['actual_windspeed'] = day['windspeed'] * 67
df['actual_hum'] = day['hum'] * 100

df['actual_season'] = day['season'].replace([1,2,3,4],["Spring","Summer","Fall","Winter"])
df['actual_yr'] = day['yr'].replace([0,1],["2011","2012"])
df['actual_holiday'] = day['holiday'].replace([0,1],["Working day","Holiday"])
df['actual_weathersit'] = day['weathersit'].replace([1,2,3,4],["Clear","Cloudy/Mist","Rain/Snow/Fog","Heavy Rain/Snow/Fog"])

# %%
df
# Out:
#      instant      dteday  season  yr  mnth  holiday  weekday  workingday  \
# 0          1  2011-01-01       1   0     1        0        6           0
# 1          2  2011-01-02       1   0     1        0        0           0
# 2          3  2011-01-03       1   0     1        0        1           1
# 3          4  2011-01-04       1   0     1        0        2           1
# 4          5  2011-01-05       1   0     1        0        3           1
# 5          6  2011-01-06       1   0     1        0        4           1
# 6          7  2011-01-07       1   0     1        0        5           1
# 7          8  2011-01-08       1   0     1        0        6           0
# 8          9  2011-01-09       1   0     1        0        0           0
# 9         10  2011-01-10       1   0     1        0        1           1
# 10        11  2011-01-11       1   0     1        0        2           1
# 11        12  2011-01-12       1   0     1        0        3           1
# 12        13  2011-01-13       1   0     1        0        4           1
# 13        14  2011-01-14       1   0     1        0        5           1
# 14        15  2011-01-15       1   0     1        0        6           0
# 15        16  2011-01-16       1   0     1        0        0           0
# 16        17  2011-01-17       1   0     1        1        1           0
# 17        18  2011-01-18       1   0     1        0        2           1
# 18        19  2011-01-19       1   0     1        0        3           1
# 19        20  2011-01-20       1   0     1        0        4           1
# 20        21  2011-01-21       1   0     1        0        5           1
# 21        22  2011-01-22       1   0     1        0        6           0
# 22        23  2011-01-23       1   0     1        0        0           0
# 23        24  2011-01-24       1   0     1        0        1           1
# 24        25  2011-01-25       1   0     1        0        2           1
# 25        26  2011-01-26       1   0     1        0        3           1
# 26        27  2011-01-27       1   0     1        0        4           1
# 27        28  2011-01-28       1   0     1        0        5           1
# 28        29  2011-01-29       1   0     1        0        6           0
# 29        30  2011-01-30       1   0     1        0        0           0
# ..       ...         ...     ...  ..   ...      ...      ...         ...
# 701      702  2012-12-02       4   1    12        0        0           0
# 702      703  2012-12-03       4   1    12        0        1           1
# 703      704  2012-12-04       4   1    12        0        2           1
# 704      705  2012-12-05       4   1    12        0        3           1
# 705      706  2012-12-06       4   1    12        0        4           1
# 706      707  2012-12-07       4   1    12        0        5           1
# 707      708  2012-12-08       4   1    12        0        6           0
# 708      709  2012-12-09       4   1    12        0        0           0
# 709      710  2012-12-10       4   1    12        0        1           1
# 710      711  2012-12-11       4   1    12        0        2           1
# 711      712  2012-12-12       4   1    12        0        3           1
# 712      713  2012-12-13       4   1    12        0        4           1
# 713      714  2012-12-14       4   1    12        0        5           1
# 714      715  2012-12-15       4   1    12        0        6           0
# 715      716  2012-12-16       4   1    12        0        0           0
# 716      717  2012-12-17       4   1    12        0        1           1
# 717      718  2012-12-18       4   1    12        0        2           1
# 718      719  2012-12-19       4   1    12        0        3           1
# 719      720  2012-12-20       4   1    12        0        4           1
# 720      721  2012-12-21       1   1    12        0        5           1
# 721      722  2012-12-22       1   1    12        0        6           0
# 722      723  2012-12-23       1   1    12        0        0           0
# 723      724  2012-12-24       1   1    12        0        1           1
# 724      725  2012-12-25       1   1    12        1        2           0
# 725      726  2012-12-26       1   1    12        0        3           1
# 726      727  2012-12-27       1   1    12        0        4           1
# 727      728  2012-12-28       1   1    12        0        5           1
# 728      729  2012-12-29       1   1    12        0        6           0
# 729      730  2012-12-30       1   1    12        0        0           0
# 730      731  2012-12-31       1   1    12        0        1           1
#
#      weathersit      temp        ...          registered   cnt  actual_temp  \
# 0             2  0.344167        ...                 654   985    13.422513
# 1             2  0.363478        ...                 670   801    14.175642
# 2             1  0.196364        ...                1229  1349     7.658196
# 3             1  0.200000        ...                1454  1562     7.800000
# 4             1  0.226957        ...                1518  1600     8.851323
# 5             1  0.204348        ...                1518  1606     7.969572
# 6             2  0.196522        ...                1362  1510     7.664358
# 7             2  0.165000        ...                 891   959     6.435000
# 8             1  0.138333        ...                 768   822     5.394987
# 9             1  0.150833        ...                1280  1321     5.882487
# 10            2  0.169091        ...                1220  1263     6.594549
# 11            1  0.172727        ...                1137  1162     6.736353
# 12            1  0.165000        ...                1368  1406     6.435000
# 13            1  0.160870        ...                1367  1421     6.273930
# 14            2  0.233333        ...                1026  1248     9.099987
# 15            1  0.231667        ...                 953  1204     9.035013
# 16            2  0.175833        ...                 883  1000     6.857487
# 17            2  0.216667        ...                 674   683     8.450013
# 18            2  0.292174        ...                1572  1650    11.394786
# 19            2  0.261667        ...                1844  1927    10.205013
# 20            1  0.177500        ...                1468  1543     6.922500
# 21            1  0.059130        ...                 888   981     2.306086
# 22            1  0.096522        ...                 836   986     3.764346
# 23            1  0.097391        ...                1330  1416     3.798261
# 24            2  0.223478        ...                1799  1985     8.715642
# 25            3  0.217500        ...                 472   506     8.482500
# 26            1  0.195000        ...                 416   431     7.605000
# 27            2  0.203478        ...                1129  1167     7.935642
# 28            1  0.196522        ...                 975  1098     7.664358
# 29            1  0.216522        ...                 956  1096     8.444358
# ..          ...       ...        ...                 ...   ...          ...
# 701           2  0.347500        ...                3757  4649    13.552500
# 702           1  0.452500        ...                5679  6234    17.647500
# 703           1  0.475833        ...                6055  6606    18.557487
# 704           1  0.438333        ...                5398  5729    17.094987
# 705           1  0.255833        ...                5035  5375     9.977487
# 706           2  0.320833        ...                4659  5008    12.512487
# 707           2  0.381667        ...                4429  5582    14.885013
# 708           2  0.384167        ...                2787  3228    14.982513
# 709           2  0.435833        ...                4841  5170    16.997487
# 710           2  0.353333        ...                5219  5501    13.779987
# 711           2  0.297500        ...                5009  5319    11.602500
# 712           1  0.295833        ...                5107  5532    11.537487
# 713           1  0.281667        ...                5182  5611    10.985013
# 714           1  0.324167        ...                4280  5047    12.642513
# 715           2  0.362500        ...                3248  3786    14.137500
# 716           2  0.393333        ...                4373  4585    15.339987
# 717           1  0.410833        ...                5124  5557    16.022487
# 718           1  0.332500        ...                4934  5267    12.967500
# 719           2  0.330000        ...                3814  4128    12.870000
# 720           2  0.326667        ...                3402  3623    12.740013
# 721           1  0.265833        ...                1544  1749    10.367487
# 722           1  0.245833        ...                1379  1787     9.587487
# 723           2  0.231304        ...                 746   920     9.020856
# 724           2  0.291304        ...                 573  1013    11.360856
# 725           3  0.243333        ...                 432   441     9.489987
# 726           2  0.254167        ...                1867  2114     9.912513
# 727           2  0.253333        ...                2451  3095     9.879987
# 728           2  0.253333        ...                1182  1341     9.879987
# 729           1  0.255833        ...                1432  1796     9.977487
# 730           2  0.215833        ...                2290  2729     8.417487
#
#      actual_feel_temp  actual_windspeed  actual_hum  actual_season  actual_yr  \
# 0           18.181250         10.749882     80.5833         Spring       2011
# 1           17.686950         16.652113     69.6087         Spring       2011
# 2            9.470250         16.636703     43.7273         Spring       2011
# 3           10.606100         10.739832     59.0435         Spring       2011
# 4           11.463500         12.522300     43.6957         Spring       2011
# 5           11.660450          6.000868     51.8261         Spring       2011
# 6           10.441950         11.304642     49.8696         Spring       2011
# 7            8.112700         17.875868     53.5833         Spring       2011
# 8            5.808750         24.250650     43.4167         Spring       2011
# 9            7.544400         14.958889     48.2917         Spring       2011
# 10           9.573200          8.182844     68.6364         Spring       2011
# 11           8.023650         20.410009     59.9545         Spring       2011
# 12           7.544150         20.167000     47.0417         Spring       2011
# 13           9.420650          8.478716     53.7826         Spring       2011
# 14          12.405600         10.583521     49.8750         Spring       2011
# 15          11.710850         12.625011     48.3750         Spring       2011
# 16           8.838550         12.999139     53.7500         Spring       2011
# 17          11.616650          9.833925     86.1667         Spring       2011
# 18          14.921100         13.957239     74.1739         Spring       2011
# 19          12.752500         13.125568     53.8333         Spring       2011
# 20           7.891650         23.667214     45.7083         Spring       2011
# 21           3.953480         11.521990     40.0000         Spring       2011
# 22           4.941955         16.522200     43.6522         Spring       2011
# 23           5.896500         10.608110     49.1739         Spring       2011
# 24          11.726300          8.696332     61.6957         Spring       2011
# 25          10.180000         19.687950     86.2500         Spring       2011
# 26          10.985000          7.627079     68.7500         Spring       2011
# 27          11.165850          8.261100     79.3043         Spring       2011
# 28          10.606300          9.739455     65.1739         Spring       2011
# 29          12.516100          4.956834     72.2174         Spring       2011
# ..                ...               ...         ...            ...        ...
# 701         17.960400          8.333393     82.3333         Winter       2012
# 702         22.789800          5.542294     76.7500         Winter       2012
# 703         23.452700         11.666643     73.3750         Winter       2012
# 704         21.400600         21.709407     48.5000         Winter       2012
# 705         12.910200         11.708518     50.8750         Winter       2012
# 706         16.097900          8.750200     76.4167         Winter       2012
# 707         19.475400          6.792393     91.1250         Winter       2012
# 708         19.507300         10.584325     90.5417         Winter       2012
# 709         21.778750         12.750636     92.5000         Winter       2012
# 710         16.918150         19.834479     59.6667         Winter       2012
# 711         14.866900         10.916779     53.8333         Winter       2012
# 712         14.709400         11.666643     48.5833         Winter       2012
# 713         14.709600          8.792343     64.2917         Winter       2012
# 714         16.919150          7.125450     65.0417         Winter       2012
# 715         18.496900          6.749714     83.8750         Winter       2012
# 716         20.075000          6.583306     90.7083         Winter       2012
# 717         20.485400         14.834068     66.6250         Winter       2012
# 718         17.108100         12.334164     62.5417         Winter       2012
# 719         16.760850          8.875021     66.7917         Winter       2012
# 720         15.088350         25.083661     55.6667         Spring       2012
# 721         11.805650         27.292182     44.1250         Spring       2012
# 722         12.973550          8.916561     51.5417         Spring       2012
# 723         12.945000          5.174437     79.1304         Spring       2012
# 724         14.723250         11.304642     73.4783         Spring       2012
# 725         11.016650         21.208582     82.3333         Spring       2012
# 726         11.332100         23.458911     65.2917         Spring       2012
# 727         12.752300         10.416557     59.0000         Spring       2012
# 728         12.120000          8.333661     75.2917         Spring       2012
# 729         11.585000         23.500518     48.3333         Spring       2012
# 730         11.174350         10.374682     57.7500         Spring       2012
#
#      actual_holiday  actual_weathersit
# 0       Working day        Cloudy/Mist
# 1       Working day        Cloudy/Mist
# 2       Working day              Clear
# 3       Working day              Clear
# 4       Working day              Clear
# 5       Working day              Clear
# 6       Working day        Cloudy/Mist
# 7       Working day        Cloudy/Mist
# 8       Working day              Clear
# 9       Working day              Clear
# 10      Working day        Cloudy/Mist
# 11      Working day              Clear
# 12      Working day              Clear
# 13      Working day              Clear
# 14      Working day        Cloudy/Mist
# 15      Working day              Clear
# 16          Holiday        Cloudy/Mist
# 17      Working day        Cloudy/Mist
# 18      Working day        Cloudy/Mist
# 19      Working day        Cloudy/Mist
# 20      Working day              Clear
# 21      Working day              Clear
# 22      Working day              Clear
# 23      Working day              Clear
# 24      Working day        Cloudy/Mist
# 25      Working day      Rain/Snow/Fog
# 26      Working day              Clear
# 27      Working day        Cloudy/Mist
# 28      Working day              Clear
# 29      Working day              Clear
# ..              ...                ...
# 701     Working day        Cloudy/Mist
# 702     Working day              Clear
# 703     Working day              Clear
# 704     Working day              Clear
# 705     Working day              Clear
# 706     Working day        Cloudy/Mist
# 707     Working day        Cloudy/Mist
# 708     Working day        Cloudy/Mist
# 709     Working day        Cloudy/Mist
# 710     Working day        Cloudy/Mist
# 711     Working day        Cloudy/Mist
# 712     Working day              Clear
# 713     Working day              Clear
# 714     Working day              Clear
# 715     Working day        Cloudy/Mist
# 716     Working day        Cloudy/Mist
# 717     Working day              Clear
# 718     Working day              Clear
# 719     Working day        Cloudy/Mist
# 720     Working day        Cloudy/Mist
# 721     Working day              Clear
# 722     Working day              Clear
# 723     Working day        Cloudy/Mist
# 724         Holiday        Cloudy/Mist
# 725     Working day      Rain/Snow/Fog
# 726     Working day        Cloudy/Mist
# 727     Working day        Cloudy/Mist
# 728     Working day        Cloudy/Mist
# 729     Working day              Clear
# 730     Working day        Cloudy/Mist
#
# [731 rows x 24 columns]

# %%
#Check the data types od variables
df.dtypes
# Out:
# instant                int64
# dteday                object
# season                 int64
# yr                     int64
# mnth                   int64
# holiday                int64
# weekday                int64
# workingday             int64
# weathersit             int64
# temp                 float64
# atemp                float64
# hum                  float64
# windspeed            float64
# casual                 int64
# registered             int64
# cnt                    int64
# actual_temp          float64
# actual_feel_temp     float64
# actual_windspeed     float64
# actual_hum           float64
# actual_season         object
# actual_yr             object
# actual_holiday        object
# actual_weathersit     object
# dtype: object

# %%
#Change the data types
df['weathersit'] = df['weathersit'].astype('category')
df['holiday'] = df['holiday'].astype('category')
df['yr'] = df['yr'].astype('category')
df['season'] = df['season'].astype('category')
df['workingday'] = df['workingday'].astype('category')
df['weekday'] = df['weekday'].astype('category')
df['mnth'] = df['mnth'].astype('category')
df['actual_season'] = df['actual_season'].astype('category')
df['actual_yr'] = df['actual_yr'].astype('category')
df['actual_holiday'] = df['actual_holiday'].astype('category')
df['actual_weathersit'] = df['actual_weathersit'].astype('category')

df.dtypes
# Out:
# instant                 int64
# dteday                 object
# season               category
# yr                   category
# mnth                 category
# holiday              category
# weekday              category
# workingday           category
# weathersit           category
# temp                  float64
# atemp                 float64
# hum                   float64
# windspeed             float64
# casual                  int64
# registered              int64
# cnt                     int64
# actual_temp           float64
# actual_feel_temp      float64
# actual_windspeed      float64
# actual_hum            float64
# actual_season        category
# actual_yr            category
# actual_holiday       category
# actual_weathersit    category
# dtype: object

# %%
#Check the count of values of categorical variables
print(df.workingday.value_counts())
print(df.weekday.value_counts())
print(df.mnth.value_counts())
print(df.actual_yr.value_counts())
print(df.actual_holiday.value_counts())
print(df.actual_weathersit.value_counts())
# Out:
# 1    500
# 0    231
# Name: workingday, dtype: int64
# 6    105
# 1    105
# 0    105
# 5    104
# 4    104
# 3    104
# 2    104
# Name: weekday, dtype: int64
# 12    62
# 10    62
# 8     62
# 7     62
# 5     62
# 3     62
# 1     62
# 11    60
# 9     60
# 6     60
# 4     60
# 2     57
# Name: mnth, dtype: int64
# 2012    366
# 2011    365
# Name: actual_yr, dtype: int64
# Working day    710
# Holiday         21
# Name: actual_holiday, dtype: int64
# Clear            463
# Cloudy/Mist      247
# Rain/Snow/Fog     21
# Name: actual_weathersit, dtype: int64

# %%
#Check if there are missing values
df.isnull().sum()
# Out:
# instant              0
# dteday               0
# season               0
# yr                   0
# mnth                 0
# holiday              0
# weekday              0
# workingday           0
# weathersit           0
# temp                 0
# atemp                0
# hum                  0
# windspeed            0
# casual               0
# registered           0
# cnt                  0
# actual_temp          0
# actual_feel_temp     0
# actual_windspeed     0
# actual_hum           0
# actual_season        0
# actual_yr            0
# actual_holiday       0
# actual_weathersit    0
# dtype: int64

# %%
df.head()
# Out:
#    instant      dteday season yr mnth holiday weekday workingday weathersit  \
# 0        1  2011-01-01      1  0    1       0       6          0          2
# 1        2  2011-01-02      1  0    1       0       0          0          2
# 2        3  2011-01-03      1  0    1       0       1          1          1
# 3        4  2011-01-04      1  0    1       0       2          1          1
# 4        5  2011-01-05      1  0    1       0       3          1          1
#
#        temp        ...          registered   cnt  actual_temp  \
# 0  0.344167        ...                 654   985    13.422513
# 1  0.363478        ...                 670   801    14.175642
# 2  0.196364        ...                1229  1349     7.658196
# 3  0.200000        ...                1454  1562     7.800000
# 4  0.226957        ...                1518  1600     8.851323
#
#    actual_feel_temp  actual_windspeed  actual_hum  actual_season  actual_yr  \
# 0          18.18125         10.749882     80.5833         Spring       2011
# 1          17.68695         16.652113     69.6087         Spring       2011
# 2           9.47025         16.636703     43.7273         Spring       2011
# 3          10.60610         10.739832     59.0435         Spring       2011
# 4          11.46350         12.522300     43.6957         Spring       2011
#
#    actual_holiday  actual_weathersit
# 0     Working day        Cloudy/Mist
# 1     Working day        Cloudy/Mist
# 2     Working day              Clear
# 3     Working day              Clear
# 4     Working day              Clear
#
# [5 rows x 24 columns]

# %%
#Check the bar graph of categorical Data using factorplot
sns.set_style("whitegrid")
sns.factorplot(data=df, x='actual_season', kind= 'count',size=4,aspect=2)
#sns.factorplot(data=df, x='actual_weathersit', kind= 'count',size=4,aspect=2)
#sns.factorplot(data=df, x='workingday', kind= 'count',size=4,aspect=2)
# Out:
# C:\Users\Pc\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Pc\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
#sns.factorplot(data=df, x='actual_season', kind= 'count',size=4,aspect=2)
sns.factorplot(data=df, x='actual_weathersit', kind= 'count',size=4,aspect=2)
#sns.factorplot(data=df, x='workingday', kind= 'count',size=4,aspect=2)
# Out:
# C:\Users\Pc\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Pc\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
sns.set_style("whitegrid")
#sns.factorplot(data=df, x='actual_season', kind= 'count',size=4,aspect=2)
#sns.factorplot(data=df, x='actual_weathersit', kind= 'count',size=4,aspect=2)
sns.factorplot(data=df, x='workingday', kind= 'count',size=4,aspect=2)
# Out:
# C:\Users\Pc\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\Pc\Anaconda3\lib\site-packages\seaborn\categorical.py:3672: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Check the distribution of numerical data using histogram
plt.hist(data=df, x='actual_temp', bins='auto', label='Temperature')
plt.xlabel('Temperature in Celcius')
plt.title("Temperature Distribution")
# Out:
# Text(0.5, 1.0, 'Temperature Distribution')

# %%
#Check the distribution of numerical data using histogram
plt.hist(data=df, x='actual_feel_temp', bins='auto', label='Temperature')
plt.xlabel('Actual feeling Temperature in Celcius')
plt.title("Actual feeling Temperature Distribution")
# Out:
# Text(0.5, 1.0, 'Actual feeling Temperature Distribution')

# %%
#Check the distribution of numerical data using histogram
plt.hist(data=df, x='actual_hum', bins='auto', label='Temperature')
plt.xlabel('Humidity')
plt.title("Humidity Distribution")
# Out:
# Text(0.5, 1.0, 'Humidity Distribution')

# %%
#Check the distribution of numerical data using histogram
plt.hist(data=df, x='actual_windspeed', bins='auto', label='Windspeed')
plt.xlabel('Windspeed')
plt.title("windspeed Distribution")
# Out:
# Text(0.5, 1.0, 'windspeed Distribution')

# %%
#Check for outliers in data using boxplot
sns.boxplot(data=df[['actual_temp','actual_feel_temp','actual_windspeed','actual_hum']])
fig=plt.gcf()
fig.set_size_inches(6,6)

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['actual_hum'].values).set_title("Distribution of Actual Humidity")
# Out:
# C:\Users\Pc\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval
# Text(0.5, 1.0, 'Distribution of Actual Humidity')

# %%
df.loc[df['actual_hum']<30].shape
# Out:
# (5, 24)

# %%
df.loc[df['actual_hum']>90].shape
# Out:
# (19, 24)

# %% [markdown]
# Remove outliers in Humidity

# %%
df=df.loc[df['actual_hum'].between(30,90)]

# %%
#Remove outliers in Humidity
#q75, q25 = np.percentile(df['actual_hum'], [75 ,25])
#print(q75,q25)
#iqr = q75 - q25
#print(iqr)
#min = q25 - (iqr*1.5)
#max = q75 + (iqr*1.5)
#print(min)
#print(max)

#df = df.drop(df[df.iloc[:,19] < min].index)
#df = df.drop(df[df.iloc[:,19] > max].index)

# %%
plt.figure(figsize=(8,5))
sns.kdeplot(df['actual_windspeed'].values).set_title("Distribution of Actual windspeed")
# Out:
# Text(0.5, 1.0, 'Distribution of Actual windspeed')

# %%
df.loc[df['actual_windspeed']<4].shape
# Out:
# (12, 24)

# %%
df.loc[df['actual_windspeed']>25].shape
# Out:
# (16, 24)

# %% [markdown]
# Removing Outliers in actual windspeed

# %%
df=df.loc[df['actual_windspeed'].between(4,25)]

# %%
#Remove outliers in Windspeed
#q75, q25 = np.percentile(df['actual_windspeed'], [75 ,25])
#print(q75,q25)
#iqr = q75 - q25
#print(iqr)
#min = q25 - (iqr*1.5)
#max = q75 + (iqr*1.5)
#print(min)
#print(max)

#df = df.drop(df[df.iloc[:,18] < min].index)
#df = df.drop(df[df.iloc[:,18] > max].index)

# %%
#Check for outliers in data using boxplot after removing outliers
sns.boxplot(data=df[['actual_temp','actual_feel_temp','actual_windspeed','actual_hum']])
fig=plt.gcf()
fig.set_size_inches(6,6)

# %%
#Check distribution of cnt
plt.figure(figsize=(8,5))
sns.kdeplot(df['cnt'].values).set_title("Distribution of count of bikes rented")
# Out:
# Text(0.5, 1.0, 'Distribution of count of bikes rented')

# %%
df.loc[df['cnt']<100].shape
# Out:
# (1, 24)

# %%
df.loc[df['cnt']>8000].shape
# Out:
# (12, 24)

# %%
#df=df.loc[df['cnt'].between(100,8000)]

# %%
#Check for collinearity using corelation matrix.
cor_mat= df[:].corr()
mask = np.array(cor_mat)
mask[np.tril_indices_from(mask)] = False
fig=plt.gcf()
fig.set_size_inches(30,12)
sns.heatmap(data=cor_mat,mask=mask,square=True,annot=True,cbar=True)

# %%
#Check the distribution of Temperature and Humdity against Bike rental count using scatter plot
fig, axs = plt.subplots(1,2, figsize=(15, 5), sharey=True)
axs[0].scatter(data=df, x='actual_temp', y='cnt')
axs[1].scatter(data=df, x='actual_hum', y='cnt', color = 'red')
fig.suptitle('Scatter plot for Temperature and Humidity')
plt.xlabel("Humidity")
plt.ylabel("Count of bikes")
# Out:
# Text(0, 0.5, 'Count of bikes')

# %%
#Check the distribution of actual temperature and season.
plt.scatter(x=df['actual_season'],y=df['actual_temp'])
plt.xlabel("Season")
plt.ylabel("Temperature")
# Out:
# Text(0, 0.5, 'Temperature')

# %%
#Check the distribution of Feel Temperature and Windspeed against Bike rental count using scatter plot
fig, axs = plt.subplots(1,2, figsize=(15, 5), sharey=True)
axs[0].scatter(data=df, x='actual_feel_temp', y='cnt')
axs[1].scatter(data=df, x='actual_windspeed', y='cnt', color = 'red')
fig.suptitle('Scatter plot for Feel Temperature and Windspeed')
plt.xlabel("Windspeed")
plt.ylabel("Count of bikes")
# Out:
# Text(0, 0.5, 'Count of bikes')

# %%
#Check the distribution of actual season againt bike rental count
plt.scatter(x=df['cnt'],y=df['actual_season'])
plt.xlabel("Count of Bikes")
plt.ylabel("Season")
# Out:
# Text(0, 0.5, 'Season')

# %%
df = df.drop(columns=['holiday','instant','dteday','atemp','casual','registered','actual_temp','actual_feel_temp',
                      'actual_windspeed','actual_hum','actual_season','actual_yr','actual_holiday','actual_weathersit'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 679 entries, 0 to 730
# Data columns (total 10 columns):
# season        679 non-null category
# yr            679 non-null category
# mnth          679 non-null category
# weekday       679 non-null category
# workingday    679 non-null category
# weathersit    679 non-null category
# temp          679 non-null float64
# hum           679 non-null float64
# windspeed     679 non-null float64
# cnt           679 non-null int64
# dtypes: category(6), float64(3), int64(1)
# memory usage: 31.8 KB

# %% [markdown]
# # Modelling

# %% [markdown]
# ### Linear Regression

# %%
#import libraries for Linear regression
import statsmodels.api as sm
from sklearn.metrics import mean_squared_error

# %%
#Divide data into train and test
from sklearn.model_selection import train_test_split
train,test = train_test_split(df, test_size = 0.2, random_state = 123)

# %%
#Train the model
lr_model = sm.OLS(train.iloc[:,9].astype(float), train.iloc[:,0:9].astype(float)).fit()

# %%
#Check the summary of model
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.966
# Model:                            OLS   Adj. R-squared:                  0.966
# Method:                 Least Squares   F-statistic:                     1708.
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):               0.00
# Time:                        23:21:37   Log-Likelihood:                -4468.4
# No. Observations:                 543   AIC:                             8955.
# Df Residuals:                     534   BIC:                             8993.
# Df Model:                           9
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# season       574.0465     67.042      8.563      0.000     442.349     705.744
# yr          2061.1104     78.381     26.296      0.000    1907.137    2215.084
# mnth         -41.4770     20.867     -1.988      0.047     -82.468      -0.486
# weekday      109.0498     19.099      5.710      0.000      71.532     146.567
# workingday   247.2195     83.288      2.968      0.003      83.607     410.832
# weathersit  -635.1777     99.946     -6.355      0.000    -831.514    -438.842
# temp        5447.4887    232.831     23.397      0.000    4990.111    5904.866
# hum          243.5469    323.733      0.752      0.452    -392.399     879.492
# windspeed   -764.0947    482.328     -1.584      0.114   -1711.588     183.398
# ==============================================================================
# Omnibus:                       73.183   Durbin-Watson:                   2.134
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              158.755
# Skew:                          -0.743   Prob(JB):                     3.36e-35
# Kurtosis:                       5.193   Cond. No.                         104.
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %%
#Predict the results of test data
lr_predictions = lr_model.predict(test.iloc[:,0:9])

# %%
##Create a dataframe for actual values and predicted values
df_lr = pd.DataFrame({'actual': test.iloc[:,9], 'pred': lr_predictions})
df_lr.head()
# Out:
#      actual     pred
# 170    4010  3507.25
# 206    4590  5444.29
# 374    3598  4119.59
# 697    5260  5418.54
# 661    7466  6821.05

# %%
#Function for Mean Absolute Percentage Error
def MAPE(y_actual,y_pred):
    mape = np.mean(np.abs((y_actual - y_pred)/y_actual))*100
    return mape

# %%
#Calclulate MAPE
MAPE(test.iloc[:,9],lr_predictions)
# Out:
# 12.595824622052007

# %%
#Create continuous data. Save target variable first
train_lr = train[['cnt','temp','hum','windspeed']]
test_lr = test[['cnt','temp','hum','windspeed']]

# %%
#Create dummies for categorical variables
cat_names = ["season", "yr", "mnth", "weekday", "workingday", "weathersit"]

for i in cat_names:
    temp1 = pd.get_dummies(train[i], prefix = i)
    temp2 = pd.get_dummies(test[i], prefix = i)
    train_lr = train_lr.join(temp1)
    test_lr = test_lr.join(temp2)

# %%
#Train the model
lr_model = sm.OLS(train_lr.iloc[:,0].astype(float), train_lr.iloc[:,1:34].astype(float)).fit()

# %%
#summary of model
lr_model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    cnt   R-squared:                       0.847
# Model:                            OLS   Adj. R-squared:                  0.839
# Method:                 Least Squares   F-statistic:                     105.7
# Date:                Fri, 19 Jul 2019   Prob (F-statistic):          1.17e-190
# Time:                        23:21:38   Log-Likelihood:                -4372.2
# No. Observations:                 543   AIC:                             8800.
# Df Residuals:                     515   BIC:                             8921.
# Df Model:                          27
# Covariance Type:            nonrobust
# ================================================================================
#                    coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------
# temp          4078.6699    487.924      8.359      0.000    3120.104    5037.236
# hum          -1553.5796    371.444     -4.183      0.000   -2283.312    -823.848
# windspeed    -2524.9243    538.632     -4.688      0.000   -3583.111   -1466.738
# season_1      -419.6477    146.881     -2.857      0.004    -708.208    -131.088
# season_2       532.7972    148.737      3.582      0.000     240.592     825.002
# season_3       362.8913    156.638      2.317      0.021      55.163     670.620
# season_4      1281.9847    154.007      8.324      0.000     979.425    1584.545
# yr_0          -125.4717    105.836     -1.186      0.236    -333.396      82.453
# yr_1          1883.4973    102.407     18.392      0.000    1682.310    2084.684
# mnth_1        -284.1970    201.552     -1.410      0.159    -680.163     111.769
# mnth_2         -79.9704    195.583     -0.409      0.683    -464.209     304.268
# mnth_3         250.1549    151.018      1.656      0.098     -46.532     546.841
# mnth_4         234.9104    177.840      1.321      0.187    -114.471     584.292
# mnth_5         563.4619    187.444      3.006      0.003     195.213     931.711
# mnth_6         382.0783    181.931      2.100      0.036      24.659     739.497
# mnth_7          30.6157    215.529      0.142      0.887    -392.808     454.040
# mnth_8         438.6911    202.316      2.168      0.031      41.226     836.157
# mnth_9         886.2934    165.347      5.360      0.000     561.455    1211.132
# mnth_10        208.1912    189.127      1.101      0.271    -163.365     579.747
# mnth_11       -451.7372    202.343     -2.233      0.026    -849.257     -54.218
# mnth_12       -420.4667    172.274     -2.441      0.015    -758.912     -82.021
# weekday_0      199.7087    158.006      1.264      0.207    -110.707     510.124
# weekday_1      -22.2449     95.102     -0.234      0.815    -209.080     164.590
# weekday_2      123.1305    110.915      1.110      0.267     -94.770     341.031
# weekday_3      246.9778    108.427      2.278      0.023      33.964     459.991
# weekday_4      195.6925    110.430      1.772      0.077     -21.255     412.641
# weekday_5      291.2700    105.937      2.749      0.006      83.148     499.392
# weekday_6      723.4908    157.601      4.591      0.000     413.870    1033.111
# workingday_0   677.8177    149.397      4.537      0.000     384.315     971.320
# workingday_1  1080.2079    130.269      8.292      0.000     824.283    1336.132
# weathersit_1  1508.3159     95.846     15.737      0.000    1320.018    1696.613
# weathersit_2  1033.6168    100.502     10.284      0.000     836.172    1231.062
# weathersit_3  -783.9071    224.920     -3.485      0.001   -1225.781    -342.033
# ==============================================================================
# Omnibus:                       79.370   Durbin-Watson:                   2.024
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              218.323
# Skew:                          -0.720   Prob(JB):                     3.91e-48
# Kurtosis:                       5.753   Cond. No.                     1.87e+16
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.3e-30. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
#Predict the results of test data
lr_predictions = lr_model.predict(test_lr.iloc[:,1:34])

# %%
#Create a dataframe for actual values and predicted values
df_lr = pd.DataFrame({'actual': test_lr.iloc[:,0], 'pred': lr_predictions})
df_lr.head()
# Out:
#      actual         pred
# 170    4010  3919.017513
# 206    4590  4781.201002
# 374    3598  3672.397954
# 697    5260  5440.446412
# 661    7466  7069.203300

# %%
#Calclulate MAPE
MAPE(test_lr.iloc[:,0],lr_predictions)
# Out:
# 11.485022577004047

# %% [markdown]
# ### Decision tree

# %%
#Import Libraries for decision tree
from sklearn.tree import DecisionTreeRegressor

# %%
#Train the model
dt_model = DecisionTreeRegressor(random_state=123).fit(train.iloc[:,0:9], train.iloc[:,9])

# %%
#Predict the results of test data
dt_predictions = dt_model.predict(test.iloc[:,0:9])

# %%
dt_predictions
# Out:
# array([4539., 4326., 3777., 5495., 7001., 4302., 4169., 7870., 4451.,
#        3784., 4451., 5633., 4785., 3348., 4669., 3872., 1450., 4758.,
#        1562., 3974., 3613., 7870., 6093., 3926., 1096., 1807., 6207.,
#        5305., 7040., 5008., 2298., 3095., 4326., 7865., 6624., 1951.,
#        4266., 7525., 1787., 3744., 1406., 2425., 2133., 4660., 5566.,
#        7498., 3855., 4725., 1746., 7105., 7105., 7605., 7736., 6597.,
#        2633., 3389., 8362., 3068., 2177., 6770., 8167., 4456., 3811.,
#        3784., 3190., 5119., 4665., 6457., 1416., 5495., 4046., 4451.,
#        6196., 5478., 7639., 5302., 7347., 7525., 3141., 3846., 5740.,
#        4608., 6457., 7525., 5119., 5740., 4075., 3894., 2209., 5046.,
#        2133., 6457., 2423., 3926., 5728., 3820., 4318., 5115., 3926.,
#        3761., 4780., 1543., 4120., 2424., 6824., 4220., 6660., 4744.,
#        5375., 4844., 7058., 6392., 3071., 4266., 7865., 4978., 5687.,
#        1746., 3641., 6392., 1891., 4940., 5572., 1683., 5531., 6392.,
#        6392., 3926., 6153., 4972., 5130., 3425., 6691., 4120., 8714.,
#        6460.])

# %%
df_dt = pd.DataFrame({'actual': test.iloc[:,9], 'pred': dt_predictions})
df_dt.head()
# Out:
#      actual    pred
# 170    4010  4539.0
# 206    4590  4326.0
# 374    3598  3777.0
# 697    5260  5495.0
# 661    7466  7001.0

# %%
#!conda install -c conda-forge pydotplus --yes
#!conda install -c anaconda py-pydotplus --yes

# %%
#from sklearn.externals.six import StringIO  
#from IPython.display import Image  
#from sklearn.tree import export_graphviz
#import pydotplus
#dot_data = StringIO()
#export_graphviz(dt_model, out_file=dot_data,  
#                filled=True, rounded=True,
#                special_characters=True)
#graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
#Image(graph.create_png())

# %%
#from sklearn.metrics import mean_squared_error
#dt_rmse=np.sqrt(mean_squared_error(dt_predictions, test))
#print("RMSE for Decision Tree is ",dt_rmse)

# %%
#Function for Mean Absolute Percentage Error
#def MAPE(y_actual,y_pred):
#    mape = np.mean(np.abs((y_actual - y_pred)/y_actual))*100
#    return mape

# %%
#Calculate MAPE for decision tree
MAPE(test.iloc[:,9],dt_predictions)
# Out:
# 13.261485524817093

# %% [markdown]
# ### Random Forest

# %%
#Import library for RandomForestRegressor
from sklearn.ensemble import RandomForestRegressor

# %%
#Train the model
rf_model = RandomForestRegressor(n_estimators=500,random_state=123).fit(train.iloc[:,0:9], train.iloc[:,9])

# %%
#Predict the results of test data
rf_predictions = rf_model.predict(test.iloc[:,0:9])

# %%
#Create a dataframe for actual values and predicted values
df_rf = pd.DataFrame({'actual': test.iloc[:,9], 'pred': rf_predictions})
df_rf.head()
# Out:
#      actual      pred
# 170    4010  4567.492
# 206    4590  4311.190
# 374    3598  3929.694
# 697    5260  5402.594
# 661    7466  7350.998

# %%
#Calculate MAPE
MAPE(test.iloc[:,9],rf_predictions)
#MAPE: 9.14%
#Accuracy:90.86%
# Out:
# 9.142957036039695

# %% [markdown]
# ### X G Boost

# %%
#!conda install -c anaconda py-xgboost --yes

# %%
#from numpy import loadtxt
#from xgboost import XGBClassifier

# %%
#Train the model
#xg_model = XGBClassifier(random_state = 123).fit(train_lr.iloc[:,1:34].astype(float), train_lr.iloc[:,0].astype(float))

# %%
#xg_model

# %%
#Predict the results of test data
#xg_predictions = xg_model.predict(test_lr.iloc[:,1:34])

# %%
#Create a dataframe for actual values and predicted values
#df_xg = pd.DataFrame({'actual': test_lr.iloc[:,0], 'pred': xg_predictions})
#df_xg.head()

# %%
#Calclulate MAPE
#MAPE(test_lr.iloc[:,0],xg_predictions)
